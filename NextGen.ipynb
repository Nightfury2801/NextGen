# %%
# Cell 1: Setup and Data Loading
import pandas as pd
import numpy as np
from google.colab import drive
import os



# --- IMPORTANT ---
# Change this path to the folder in your Google Drive where you saved the 7 CSV files.
# PASTE THE CORRECT PATH HERE:
DATA_PATH =  "/content/NextGen_data"

# Load all datasets
try:
    orders_df = pd.read_csv(os.path.join(DATA_PATH, 'orders.csv'))
    delivery_performance_df = pd.read_csv(os.path.join(DATA_PATH, 'delivery_performance.csv'))
    routes_df = pd.read_csv(os.path.join(DATA_PATH, 'routes_distance.csv'))
    fleet_df = pd.read_csv(os.path.join(DATA_PATH, 'vehicle_fleet.csv'))
    costs_df = pd.read_csv(os.path.join(DATA_PATH, 'cost_breakdown.csv'))
    inventory_df = pd.read_csv(os.path.join(DATA_PATH, 'warehouse_inventory.csv'))
    feedback_df = pd.read_csv(os.path.join(DATA_PATH, 'customer_feedback.csv'))

    print("All datasets loaded successfully!")
    print(f"Loaded {len(orders_df)} orders.")
except FileNotFoundError as e:
    print(f"Error loading data: {e}")
    print(f"Please make sure your CSV files are in the following folder: {DATA_PATH}")
# Out:
# All datasets loaded successfully!
# Loaded 200 orders.

# %%
# Cell 3: Install necessary libraries
# !pip install streamlit pandas plotly pyngrok -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 53.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 86.7 MB/s eta 0:00:00

# %%
# Cell 4: Add your ngrok authtoken
# !ngrok config add-authtoken "Enter your token"
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# Cell 5: Run the app and create a public URL
from pyngrok import ngrok
import threading
import time

# Terminate any existing tunnels
ngrok.kill()

# Open a new tunnel to port 8501
public_url = ngrok.connect(8501)
print(f"🚀 Your Streamlit app is live! Access it here: {public_url}")

# Start streamlit in a background thread
def run_streamlit():
    os.system('streamlit run app.py')

thread = threading.Thread(target=run_streamlit)
thread.start()
# Out:
# 🚀 Your Streamlit app is live! Access it here: NgrokTunnel: "https://endmost-ferroelectrically-albertina.ngrok-free.dev" -> "http://localhost:8501"
